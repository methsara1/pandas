# %% [markdown]
# SMS Spam Classification using NLP

# %% [markdown]
# step1: Reading data and visualization

# %% [markdown]
# import modules

# %%
import pandas as pd
import nltk

# %% [markdown]
# Read the dataset

# %%
df = pd.read_csv("w2_position_salaries.csv", encoding = "latin-1")

# %%
df.head(5)
# Out:
#             Position  Level  Salary
# 0   Business Analyst      1   45000
# 1  Junior Consultant      2   50000
# 2  Senior Consultant      3   60000
# 3            Manager      4   80000
# 4    Country Manager      5  110000

# %%
df.shape
# Out:
# (10, 3)
